# %%
#primer punto

import numpy as np
import math
import matplotlib.pyplot as plt

radio = 10.6

area = int(math.pi * (radio ** 2))
print("El area del cirulo es",area)

rectangulo = 0
recta_b = 0
recta_a = 1.3

while(rectangulo < area ):

  recta_b += 1
  rectangulo = recta_a * recta_b
  

print("El numero mayor entero posible es",int(recta_b))
# Out:
# El area del cirulo es 352
# El numero mayor entero posible es 271

# %%
#Segundo punto
import random
valor1=1;
while valor1 !=0:
  N=float(input('Por favor ingrese un número entero'))
  valor1=N%1
  if valor1!=0:
    'Por favor solo enteros!'
valores=np.zeros(int(N))
valores2=0
for i in range (0,int(N),1):
  r=random.randint(1,6)
  valores[i]=r
  if valores[i]==6:
    valores2+=1
valores2=valores2/N
print('Los numeros aleatorios son: ',format(valores))
print('y la fracción resultante (M/N) es:',format(valores2))
# Out:
# Por favor ingrese un número entero5
# Los numeros aleatorios son:  [6. 6. 5. 2. 6.]
# y la fracción resultante (M/N) es: 0.6

# %%
pi = 0
cont = 0
error=0
error2=0
valor=0
cont2=0

n=int(input("digite el valor de los primeros n terminos."))

for i in range(0, n+1):
    pi = 8*(1/(((4*i)+1)*((4*i)+3)))
    cont = cont + pi
    error = ((np.pi-cont)/np.pi)*100
    plt.plot(i, error, 'b.')
    valor = 1/((i+1)**2)
    cont2 = cont2 + valor
    error2= ((np.pi-cont)/np.pi)*100
    plt.plot(i, error2, ',', i, error, 'r,')

plt.xlabel('N')
plt.ylabel('% error')
plt.show()
# Out:
# digite el valor de los primeros n terminos.20
